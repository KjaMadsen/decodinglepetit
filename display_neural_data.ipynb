# %%
from nilearn import image, plotting
from nilearn.masking import apply_mask, compute_epi_mask
import matplotlib.pyplot as plt
# https://nilearn.github.io/stable/index.html
# https://github.com/nipreps/fmriprep
# https://nilearn.github.io/stable/auto_examples/02_decoding/plot_haxby_glm_decoding.html#sphx-glr-auto-examples-02-decoding-plot-haxby-glm-decoding-py

# %%
file1 = "sub-Exp1s01_T1w.nii"
file2 = "sub-Exp1s01_inplaneT1.nii"
file3 = "sub-Exp1s01_inplaneT2.nii"
img = image.smooth_img(file1, fwhm="fast")

# %%
plotting.plot_anat(file1)

# %%
plotting.plot_stat_map(file1)

# %%
plotting.plot_epi(file1)

# %%
masked_img = compute_epi_mask(file1)
masked_data = apply_mask(file1, masked_img)

plt.plot(masked_data[:1000])
